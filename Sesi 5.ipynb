# %%
import numpy as np
import pandas as pd

pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
print(df)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
#
# [3 rows x 23 columns]

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %% [markdown]
# - biar muncul semua kolom, usahakan semua settingan di atas
# - precision buat mendisplay 4 angka di belakang koma jadi 2

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# Elo ratings - which power the pure Elo forecast - are a measure of team strength based on head-to-head results, margin of victory and quality or opponent

# %%
df.iloc[3]
# Out:
# gameorder                   2
# game_id          194611020CHS
# lg_id                     NBA
# _iscopy                     1
# year_id                  1947
# date_game           11/2/1946
# seasongame                  2
# is_playoffs                 0
# team_id                   NYK
# fran_id                Knicks
# pts                        47
# elo_i                 1306.72
# elo_n                 1297.07
# win_equiv               40.69
# opp_id                    CHS
# opp_fran                Stags
# opp_pts                    63
# opp_elo_i              1300.0
# opp_elo_n             1309.65
# game_location               A
# game_result                 L
# forecast                 0.37
# notes                     NaN
# Name: 3, dtype: object

# %%
df.iloc[3]["elo_i"]
# Out:
# 1306.7233

# %%
df.tail(2)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN

# %% [markdown]
# - elo i elo awal
# - elo n elo berakhir

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
# df.describe adalah data statistik yang sederhana deskriptif. bisa membuat asumsi dan perkiraan tapi harus melihat lebih detail.

# %%
df["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
df.loc[:, "team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df["fran_id"]  == "Lakers"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
df[df["fran_id"]  == "Lakers"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %% [markdown]
# mnl juga pernah atau masih ikut lakers

# %%
df[df["fran_id"]  == "Lakers"]["team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["fran_id"] == "Lakers", "team_id"]
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
df.loc[df["fran_id"] == "Lakers", ["fran_id", "team_id"]]
# Out:
#        fran_id team_id
# 1136    Lakers     MNL
# 1152    Lakers     MNL
# 1159    Lakers     MNL
# 1170    Lakers     MNL
# 1183    Lakers     MNL
# ...        ...     ...
# 126016  Lakers     LAL
# 126052  Lakers     LAL
# 126086  Lakers     LAL
# 126115  Lakers     LAL
# 126137  Lakers     LAL
#
# [6024 rows x 2 columns]

# %% [markdown]
# harus filter baris dulu, team_id, value_counts

# %%
df["team_id"] == "MNL"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: team_id, Length: 126314, dtype: bool

# %%
df.loc[df["team_id"] == "MNL"]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9701       4851  196003190LAL   NBA        0     1960   3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960   3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960   3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960   3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960   3/26/1960          84
#
# ...

# %%
df.loc[df["team_id"] == "MNL", "date_game"]
# Out:
# 1136     11/4/1948
# 1152     11/6/1948
# 1159     11/9/1948
# 1170    11/11/1948
# 1183    11/13/1948
#            ...
# 9701     3/19/1960
# 9702     3/20/1960
# 9709     3/22/1960
# 9711     3/24/1960
# 9715     3/26/1960
# Name: date_game, Length: 946, dtype: object

# %%
df.loc[df["team_id"] == "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
df.loc[df["team_id"] == "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
print(df.loc[df["team_id"] == "LAL", "date_game"].min())
print(df.loc[df["team_id"] == "LAL", "date_game"].max())
# Out:
# 1/1/1961
# 6/9/2009

# %%
df.loc[df["team_id"] == "MNL", "date_game"]
# Out:
# 1136     11/4/1948
# 1152     11/6/1948
# 1159     11/9/1948
# 1170    11/11/1948
# 1183    11/13/1948
#            ...
# 9701     3/19/1960
# 9702     3/20/1960
# 9709     3/22/1960
# 9711     3/24/1960
# 9715     3/26/1960
# Name: date_game, Length: 946, dtype: object

# %%
df.loc[df["team_id"] == "MNL", "date_game"].agg(["min", "max"])
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %% [markdown]
# bisa pake tuple atau list

# %%
df[df["team_id"] == "BOS"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 6               4  194611020PRO   NBA        1     1947   11/2/1946
# 14              8  194611050BOS   NBA        0     1947   11/5/1946
# 28             15  194611090DTF   NBA        1     1947   11/9/1946
# 40             21  194611130CHS   NBA        1     1947  11/13/1946
# 46             24  194611140STB   NBA        1     1947  11/14/1946
# ...           ...           ...   ...      ...      ...         ...
# 126141      63071  201504150MIL   NBA        1     2015   4/15/2015
# 126162      63082  201504190CLE   NBA        1     2015   4/19/2015
# 126173      63087  201504210CLE   NBA        1     2015   4/21/2015
# 126185      63093  201504230BOS   NBA        0     2015   4/23/2015
# 126205      63103  201504260BOS   NBA        0     2015   4/26/2015
#
#         seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 6                1            0     BOS  Celtics   53  1300.00  1294.85
# ...

# %%
df[df["team_id"] == "BOS"]["pts"]
# Out:
# 6          53
# 14         55
# 28         46
# 40         61
# 46         62
#          ...
# 126141    105
# 126162    100
# 126173     91
# 126185     95
# 126205     93
# Name: pts, Length: 5997, dtype: int64

# %%
df.loc[df["team_id"] == "BOS", "pts"]
# Out:
# 6          53
# 14         55
# 28         46
# 40         61
# 46         62
#          ...
# 126141    105
# 126162    100
# 126173     91
# 126185     95
# 126205     93
# Name: pts, Length: 5997, dtype: int64

# %%
df.loc[df["team_id"] == "BOS", "pts"].sum()
# Out:
# 626484

# %%
df["game_result"]
# Out:
# 0         L
# 1         W
# 2         W
# 3         L
# 4         L
#          ..
# 126309    L
# 126310    W
# 126311    L
# 126312    L
# 126313    W
# Name: game_result, Length: 126314, dtype: object

# %%
df["game_result"] == "W"
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 126309    False
# 126310     True
# 126311    False
# 126312    False
# 126313     True
# Name: game_result, Length: 126314, dtype: bool

# %%
df.loc[df["game_result"] == "W"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 1                1            0     NYK        Knicks   68  1300.00  1306.72
# ...

# %%
df.loc[df["game_result"] == "W", "team_id"]
# Out:
# 1         NYK
# 2         CHS
# 5         WSC
# 7         PRO
# 9         STB
#          ...
# 126304    CLE
# 126307    CLE
# 126308    GSW
# 126310    GSW
# 126313    GSW
# Name: team_id, Length: 63157, dtype: object

# %%
df.loc[df["game_result"] == "W", "team_id"].value_counts()
# Out:
# BOS    3517
# LAL    3134
# NYK    2855
# DET    2430
# PHI    2306
#        ...
# CHP      18
# INJ      18
# PIT      15
# DNN      11
# SDS       3
# Name: team_id, Length: 104, dtype: int64

# %% [markdown]
# ### Data Structures

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.to_numpy()
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues.index
# Out:
# Index(['Amsterdam', 'Toronto', 'Tokyo'], dtype='object')

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": [5, 8], "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    [5, 8]
# Tokyo             8
# dtype: object

# %%
city_employee_count = pd.Series({"Amsterdam": np.array([5, 8]), "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    [5, 8]
# Tokyo             8
# dtype: object

# %%
city_employee_count.loc["Amsterdam"]
# Out:
# array([5, 8])

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
city_revenues.keys()
# Out:
# Index(['Amsterdam', 'Toronto', 'Tokyo'], dtype='object')

# %%
city_employee_count.values
# Out:
# array([5, 8], dtype=int64)

# %%
city_employee_count.index
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
city_employee_count.to_numpy()
# Out:
# array([5, 8], dtype=int64)

# %%
"Tokyo" in city_employee_count.keys()
# Out:
# True

# %%
"Tokyo" in {"Amsterdam": 5, "Tokyo": 8}
# Out:
# True

# %%
"Tokyo" in {"Amsterdam": 5, "Tokyo": 8}.keys()
# Out:
# True

# %%
{"Amsterdam": 5, "Tokyo": 8}.keys()
# Out:
# dict_keys(['Amsterdam', 'Tokyo'])

# %% [markdown]
# - Series -> 1 column
# - DataFrame -> multiple columns (table)

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})

city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    # "employee_count": city_employee_count
})

city_data
# Out:
#            revenue
# Amsterdam     4200
# Toronto       8000
# Tokyo         6500

# %%
city_data = pd.DataFrame({
    # "revenue": city_revenues,
    "employee_count": city_employee_count,
    "revenue": city_revenues,
})

city_data
# Out:
#            employee_count  revenue
# Amsterdam             5.0     4200
# Tokyo                 8.0     6500
# Toronto               NaN     8000

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
type[city_data.axes]
# Out:
# type[[Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'), Index(['revenue', 'employee_count'], dtype='object')]]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
print(city_data.axes[0])  # index
print(city_data.axes[1])  # columns
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_employee_count
# Out:
# True

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"team_id" in df
# Out:
# True

# %%
0 in df
# Out:
# False

# %%
"team_id" in df.columns
# Out:
# True

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
.loc  # location
.iloc  # index location

# %%
df.loc[baris, kolom]
df.iloc[baris, kolom]

df.loc[baris]  == df.loc[baris, :]
df.loc[kolom]  # ga bisa
df.loc[:, kolom]  # : artinya semua ikut

# %%
df.loc[0:10]
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
#
# ...

# %%
df.loc[:]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.loc[5:8]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC      Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS       Celtics   53  1300.0  1294.85      40.46    PRO
# 7            0     PRO  Steamrollers   59  1300.0  1305.15      41.54    BOS
# 8            0     PIT       Ironmen   51  1300.0  1295.31      40.51    STB
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# ...

# %%
contoh = df.loc[5:8].copy()

# %%
contoh
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC      Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS       Celtics   53  1300.0  1294.85      40.46    PRO
# 7            0     PRO  Steamrollers   59  1300.0  1305.15      41.54    BOS
# 8            0     PIT       Ironmen   51  1300.0  1295.31      40.51    STB
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# ...

# %%
df.loc[:4]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.iloc[:4]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# ...

# %%
contoh.index
# Out:
# RangeIndex(start=5, stop=9, step=1)

# %%
contoh.loc[5:6]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC  Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS   Celtics   53  1300.0  1294.85      40.46    PRO
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# 6  Steamrollers       59     1300.0    1305.15             A           L
#
#    forecast notes
# 5      0.36   NaN
# 6      0.36   NaN

# %%
contoh.loc[5:6].compare(contoh.loc[[5,6], :])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# hasilnya sama kayak atas

# %%
contoh.loc[5:7]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC      Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS       Celtics   53  1300.0  1294.85      40.46    PRO
# 7            0     PRO  Steamrollers   59  1300.0  1305.15      41.54    BOS
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# 6  Steamrollers       59     1300.0    1305.15             A           L
# 7       Celtics       53     1300.0    1294.85             H           W
#
#    forecast notes
# 5      0.36   NaN
# 6      0.36   NaN
# ...

# %%
contoh.loc[[5,6]]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC  Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS   Celtics   53  1300.0  1294.85      40.46    PRO
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# 6  Steamrollers       59     1300.0    1305.15             A           L
#
#    forecast notes
# 5      0.36   NaN
# 6      0.36   NaN

# %%
contoh.iloc[5:6]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %%
contoh.iloc[0:2]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC  Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS   Celtics   53  1300.0  1294.85      40.46    PRO
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# 6  Steamrollers       59     1300.0    1305.15             A           L
#
#    forecast notes
# 5      0.36   NaN
# 6      0.36   NaN

# %%
df.loc[5:8].iloc[1:3]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 6            0     BOS       Celtics   53  1300.0  1294.85      40.46    PRO
# 7            0     PRO  Steamrollers   59  1300.0  1305.15      41.54    BOS
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 6  Steamrollers       59     1300.0    1305.15             A           L
# 7       Celtics       53     1300.0    1294.85             H           W
#
#    forecast notes
# 6      0.36   NaN
# 7      0.64   NaN

# %%
contoh.loc[:, "gameorder"]
# Out:
# 5    3
# 6    4
# 7    4
# 8    5
# Name: gameorder, dtype: int64

# %%
contoh[:, "gameorder"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\env\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\HP\anaconda3\envs\env\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\HP\anaconda3\envs\env\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 'gameorder')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 contoh[:, "gameorder"]
#
# ...

# %%
contoh["gameorder"]
# Out:
# 5    3
# 6    4
# 7    4
# 8    5
# Name: gameorder, dtype: int64

# %%
contoh[:]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC      Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS       Celtics   53  1300.0  1294.85      40.46    PRO
# 7            0     PRO  Steamrollers   59  1300.0  1305.15      41.54    BOS
# 8            0     PIT       Ironmen   51  1300.0  1295.31      40.51    STB
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# ...

# %%
contoh[["gameorder", "lg_id"]]
# Out:
#    gameorder lg_id
# 5          3   NBA
# 6          4   NBA
# 7          4   NBA
# 8          5   NBA

# %%
contoh.loc[:, ["gameorder", "game_id", "date_game", "team_id", "year_id"]]
# Out:
#    gameorder       game_id  date_game team_id  year_id
# 5          3  194611020DTF  11/2/1946     WSC     1947
# 6          4  194611020PRO  11/2/1946     BOS     1947
# 7          4  194611020PRO  11/2/1946     PRO     1947
# 8          5  194611020STB  11/2/1946     PIT     1947

# %%
contoh.iloc[:, [0,1,5,8,4]]
# Out:
#    gameorder       game_id  date_game team_id  year_id
# 5          3  194611020DTF  11/2/1946     WSC     1947
# 6          4  194611020PRO  11/2/1946     BOS     1947
# 7          4  194611020PRO  11/2/1946     PRO     1947
# 8          5  194611020STB  11/2/1946     PIT     1947

# %%
for i, col in enumerate(contoh.columns):
    print(i, col)
    break
# Out:
# 0 gameorder

# %%
contoh.columns.to_list()
# Out:
# ['gameorder',
#  'game_id',
#  'lg_id',
#  '_iscopy',
#  'year_id',
#  'date_game',
#  'seasongame',
#  'is_playoffs',
#  'team_id',
#  'fran_id',
#  'pts',
#  'elo_i',
#  'elo_n',
#  'win_equiv',
#  'opp_id',
#  'opp_fran',
#  'opp_pts',
#  'opp_elo_i',
#  'opp_elo_n',
#  'game_location',
#  'game_result',
#  'forecast',
#  'notes']

# %%
contoh.columns.to_list().index("pts")
# Out:
# 10

# %%
city_revenues.loc["Amsterdam"]
# Out:
# 4200

# %%
city_revenues.iloc[0]
# Out:
# 4200

# %%
contoh[:2]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 5            0     WSC  Capitols   50  1300.0  1320.38      43.14    DTF
# 6            0     BOS   Celtics   53  1300.0  1294.85      40.46    PRO
#
#        opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 5       Falcons       33     1300.0    1279.62             A           W
# 6  Steamrollers       59     1300.0    1305.15             A           L
#
#    forecast notes
# 5      0.36   NaN
# 6      0.36   NaN

# %%
contoh["game_id"]
# Out:
# 5    194611020DTF
# 6    194611020PRO
# 7    194611020PRO
# 8    194611020STB
# Name: game_id, dtype: object

# %%
contoh.game_id
# Out:
# 5    194611020DTF
# 6    194611020PRO
# 7    194611020PRO
# 8    194611020STB
# Name: game_id, dtype: object

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rublik's cube", "shape": "cube"}
])

# %%
toys
# Out:
#             name   shape
# 0           ball  sphere
# 1  Rublik's cube    cube

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %% [markdown]
# rekomen pake kurung siku daripada dot aja

# %% [markdown]
# ### Querying

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df["year_id"]
# Out:
# 0         1947
# 1         1947
# 2         1947
# 3         1947
# 4         1947
#           ...
# 126309    2015
# 126310    2015
# 126311    2015
# 126312    2015
# 126313    2015
# Name: year_id, Length: 126314, dtype: int64

# %%
df.loc[:, "year_id"]
# Out:
# 0         1947
# 1         1947
# 2         1947
# 3         1947
# 4         1947
#           ...
# 126309    2015
# 126310    2015
# 126311    2015
# 126312    2015
# 126313    2015
# Name: year_id, Length: 126314, dtype: int64

# %%
df.iloc[:, 4]
# Out:
# 0         1947
# 1         1947
# 2         1947
# 3         1947
# 4         1947
#           ...
# 126309    2015
# 126310    2015
# 126311    2015
# 126312    2015
# 126313    2015
# Name: year_id, Length: 126314, dtype: int64

# %%
df.iloc[:, df.columns.to_list().index("year_id")]
# Out:
# 0         1947
# 1         1947
# 2         1947
# 3         1947
# 4         1947
#           ...
# 126309    2015
# 126310    2015
# 126311    2015
# 126312    2015
# 126313    2015
# Name: year_id, Length: 126314, dtype: int64

# %%
df[df["year_id"] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
df.loc[df["year_id"] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
current_decade = df[df["year_id"] > 2010]
current_decade.shape
# Out:
# (12658, 23)

# %%
df["notes"].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 126309    True
# 126310    True
# 126311    True
# 126312    True
# 126313    True
# Name: notes, Length: 126314, dtype: bool

# %%
df[df["notes"].isnull()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df[df["notes"].notna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
games_with_notes = df[df["notes"].notna()]
games_with_notes.shape
# Out:
# (5424, 23)

# %%
df["fran_id"].str

# %%
df["fran_id"]
# Out:
# 0           Huskies
# 1            Knicks
# 2             Stags
# 3            Knicks
# 4           Falcons
#             ...
# 126309    Cavaliers
# 126310     Warriors
# 126311    Cavaliers
# 126312    Cavaliers
# 126313     Warriors
# Name: fran_id, Length: 126314, dtype: object

# %%
df["fran_id"][0].endswith("ers")
# Out:
# False

# %%
df["fran_id"][0].endswith("ies")
# Out:
# True

# %%
df["fran_id"].str.endswith("ers")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309     True
# 126310    False
# 126311     True
# 126312     True
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
df[df["fran_id"].str.endswith("ers")]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
ers = df[df["fran_id"].str.endswith("ers")]
ers.shape
# Out:
# (27797, 23)

# %%
df[
    df["fran_id"].str.endswith("ers")
]

# %%
df[
    (df["_iscopy"] == 0)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH       Huskies   66  1300.00  1293.28
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 561           281  194703080CHS   NBA        0     1947   3/8/1947
# 643           322  194703260WSC   NBA        0     1947  3/26/1947
# 872           437  194801100WSC   NBA        0     1948  1/10/1948
# 946           474  194802040NYK   NBA        0     1948   2/4/1948
# ...           ...           ...   ...      ...      ...        ...
# 126297      63149  201505250HOU   NBA        0     2015  5/25/2015
# 126298      63150  201505260CLE   NBA        0     2015  5/26/2015
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 416             38            0     CHS      Stags  109  1366.54  1372.17
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %% [markdown]
# #### Grouping

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
points = df["pts"]
points
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %%
points = df["pts"]
points.sum()
# Out:
# 12976235

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.groupby(by="team_id")

# %%
df.groupby(by="team_id").sum()
# Out:
#          gameorder  _iscopy  year_id  seasongame  is_playoffs     pts  \
# team_id
# ANA         626475       37   153504        3081            0    8704
# AND          90999       34   140400        2628            8    6193
# ATL      140484690     2004  8037631      176155          229  411248
# BAL        8065864      380  1704802       38085           53   98112
# BLB         788827      189   911169       15870           17   37219
# ...            ...      ...      ...         ...          ...     ...
# WAS       76525664      738  2959900       62016           47  142413
# WAT          74843       31   120900        1953            0    4921
# WSA         932344       57   179270        4186            7   10774
# WSB       54413597      997  3955467       87701          106  207596
# WSC         232469      144   567118        9107           20   22387
#
#             elo_i     elo_n  win_equiv  opp_pts  opp_elo_i  opp_elo_n  \
# team_id
# ...

# %%
df.groupby(by="team_id")["pts"].sum()
# Out:
# team_id
# ANA      8704
# AND      6193
# ATL    411248
# BAL     98112
# BLB     37219
#         ...
# WAS    142413
# WAT      4921
# WSA     10774
# WSB    207596
# WSC     22387
# Name: pts, Length: 104, dtype: int64

# %%
df.groupby(by="team_id", sort=False)["pts"].sum()
# Out:
# team_id
# TRH      3995
# NYK    582497
# CHS     20398
# DTF      3797
# WSC     22387
#         ...
# NOK     15444
# OKC     64930
# BRK     26481
# NOP     16727
# CHO      7721
# Name: pts, Length: 104, dtype: int64

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113684      56843  201010270SAS   NBA        0     2011  10/27/2010
# 113733      56867  201010300SAS   NBA        0     2011  10/30/2010
# 113744      56873  201011010LAC   NBA        1     2011   11/1/2010
# 113778      56890  201011030PHO   NBA        1     2011   11/3/2010
# 113824      56913  201011060SAS   NBA        0     2011   11/6/2010
# ...           ...           ...   ...      ...      ...         ...
# 126192      63097  201504240SAS   NBA        0     2015   4/24/2015
# 126209      63105  201504260SAS   NBA        0     2015   4/26/2015
# 126221      63111  201504280LAC   NBA        1     2015   4/28/2015
# 126228      63115  201504300SAS   NBA        0     2015   4/30/2015
# 126233      63117  201505020LAC   NBA        1     2015    5/2/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 113684           1            0     SAS   Spurs  122  1594.28  1599.31
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(by="year_id").count()
# Out:
#          gameorder  game_id  lg_id  _iscopy  date_game  seasongame  \
# year_id
# 2011            88       88     88       88         88          88
# 2012            80       80     80       80         80          80
# 2013           103      103    103      103        103         103
# 2014           105      105    105      105        105         105
# 2015            89       89     89       89         89          89
#
#          is_playoffs  team_id  fran_id  pts  elo_i  elo_n  win_equiv  opp_id  \
# year_id
# 2011              88       88       88   88     88     88         88      88
# 2012              80       80       80   80     80     80         80      80
# 2013             103      103      103  103    103    103        103     103
# 2014             105      105      105  105    105    105        105     105
# 2015              89       89       89   89     89     89         89      89
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(by=["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
df.copy()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba = df.copy()

# %%
nba["difference"] = nba.pts - df.pts

# %%
renamed_nba = nba.rename(
    columns={"game_result": "result", "game_location": "location"}
)

renamed_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n location result  forecast notes  \
# ...

# %%
nba["difference"].max()
# Out:
# 0

# %% [markdown]
# ga tau kok bisa beda (?)

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]

# %%
nba[elo_columns]
# Out:
#           elo_i    elo_n  opp_elo_i  opp_elo_n
# 0       1300.00  1293.28    1300.00    1306.72
# 1       1300.00  1306.72    1300.00    1293.28
# 2       1300.00  1309.65    1306.72    1297.07
# 3       1306.72  1297.07    1300.00    1309.65
# 4       1300.00  1279.62    1300.00    1320.38
# ...         ...      ...        ...        ...
# 126309  1723.41  1704.39    1790.96    1809.98
# 126310  1809.98  1813.63    1704.39    1700.74
# 126311  1704.39  1700.74    1809.98    1813.63
# 126312  1700.74  1692.09    1813.63    1822.29
# 126313  1813.63  1822.29    1700.74    1692.09
#
# [126314 rows x 4 columns]

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.drop(elo_columns, axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.drop(columns=elo_columns)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.drop(columns=elo_columns, inplace=True)

# %%
nba = nba.drop(columns=elo_columns)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.shape
# Out:
# (126314, 20)

# %% [markdown]
# ### Data type

# %%
nba["date_game"]
# Out:
# 0         11/1/1946
# 1         11/1/1946
# 2         11/2/1946
# 3         11/2/1946
# 4         11/2/1946
#             ...
# 126309    6/11/2015
# 126310    6/14/2015
# 126311    6/14/2015
# 126312    6/16/2015
# 126313    6/16/2015
# Name: date_game, Length: 126314, dtype: object

# %%
pd.to_datetime(nba["date_game"])
# Out:
# 0        1946-11-01
# 1        1946-11-01
# 2        1946-11-02
# 3        1946-11-02
# 4        1946-11-02
#             ...
# 126309   2015-06-11
# 126310   2015-06-14
# 126311   2015-06-14
# 126312   2015-06-16
# 126313   2015-06-16
# Name: date_game, Length: 126314, dtype: datetime64[ns]

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])

# %% [markdown]
# buat ngubah data

# %%
nba["date_game"]
# Out:
# 0        1946-11-01
# 1        1946-11-01
# 2        1946-11-02
# 3        1946-11-02
# 4        1946-11-02
#             ...
# 126309   2015-06-11
# 126310   2015-06-14
# 126311   2015-06-14
# 126312   2015-06-16
# 126313   2015-06-16
# Name: date_game, Length: 126314, dtype: datetime64[ns]

# %%
nba["game_location"]
# Out:
# 0         H
# 1         A
# 2         H
# 3         A
# 4         H
#          ..
# 126309    H
# 126310    H
# 126311    A
# 126312    H
# 126313    A
# Name: game_location, Length: 126314, dtype: object

# %%
nba["game_location"].unique()
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
nba["game_location"].nunique()
# Out:
# 3

# %%
nba["game_location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba[nba["game_location"] == "N"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 64302       32152  199011020UTA   NBA        1     1991 1990-11-02
# 64303       32152  199011020UTA   NBA        0     1991 1990-11-02
# 64318       32160  199011030PHO   NBA        1     1991 1990-11-03
# 64319       32160  199011030PHO   NBA        0     1991 1990-11-03
# 69000       34501  199211060HOU   NBA        0     1993 1992-11-06
# 69001       34501  199211060HOU   NBA        1     1993 1992-11-06
# 69030       34516  199211070SEA   NBA        1     1993 1992-11-07
# 69031       34516  199211070SEA   NBA        0     1993 1992-11-07
# 73736       36869  199411040LAC   NBA        0     1995 1994-11-04
# 73737       36869  199411040LAC   NBA        1     1995 1994-11-04
# 73766       36884  199411050POR   NBA        1     1995 1994-11-05
# 73767       36884  199411050POR   NBA        0     1995 1994-11-05
# 78694       39348  199611070NJN   NBA        1     1997 1996-11-07
# ...

# %%
pd.Categorical(nba["game_location"])
# Out:
# ['H', 'A', 'H', 'A', 'H', ..., 'H', 'H', 'A', 'H', 'A']
# Length: 126314
# Categories (3, object): ['A', 'H', 'N']

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %%
nba.isna()
# Out:
#         gameorder  game_id  lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           False    False  False    False    False      False       False
# 1           False    False  False    False    False      False       False
# 2           False    False  False    False    False      False       False
# 3           False    False  False    False    False      False       False
# 4           False    False  False    False    False      False       False
# ...           ...      ...    ...      ...      ...        ...         ...
# 126309      False    False  False    False    False      False       False
# 126310      False    False  False    False    False      False       False
# 126311      False    False  False    False    False      False       False
# 126312      False    False  False    False    False      False       False
# 126313      False    False  False    False    False      False       False
#
# ...

# %%
nba.dropna()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930             28            0     WSC      Capitols   71      47.07    BLB
# ...

# %%
rows_without_missing_data = nba.dropna()
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
nba.dropna(axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
rows_without_missing_columns = nba.dropna(axis=1)
rows_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes["notes"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 126309    NaN
# 126310    NaN
# 126311    NaN
# 126312    NaN
# 126313    NaN
# Name: notes, Length: 126314, dtype: object

# %%
data_with_default_notes[data_with_default_notes["notes"].notna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930             28            0     WSC      Capitols   71      47.07    BLB
# ...

# %%
data_with_default_notes[data_with_default_notes["notes"].isna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)

# %%
data_with_default_notes["notes"]
# Out:
# 0         no notes at all
# 1         no notes at all
# 2         no notes at all
# 3         no notes at all
# 4         no notes at all
#                ...
# 126309    no notes at all
# 126310    no notes at all
# 126311    no notes at all
# 126312    no notes at all
# 126313    no notes at all
# Name: notes, Length: 126314, dtype: object

# %%
data_with_default_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %%
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast  difference
# count  126314.00  126314.00  126314.00    126314.0
# mean       41.71     102.73       0.50         0.0
# std        10.63      14.81       0.22         0.0
# min        10.15       0.00       0.02         0.0
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L      0.33  at Richmond VA; forfeit to VIR
#
#        difference
# 26684           0

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["game_result"] != 'L')].empty
# Out:
# True

# %% [markdown]
# ### Combining Datasets

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
pd.concat([city_data, further_city_data])
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %% [markdown]
# buat gabung data

# %%
pd.concat([city_data, further_city_data], axis=0)
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
all_city_data = pd.concat([city_data, further_city_data], axis=0)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
pd.concat([all_city_data, city_countries], axis=1)
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="outer")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, join="outer")
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
countries = pd.DataFrame({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland", "Japan", "Canada"])
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %%
# %matplotlib inline

# %%
nba["fran_id"] == "Knicks"
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
nba[nba["fran_id"] == "Knicks"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 23             12  194611070STB   NBA        1     1947 1946-11-07
# 37             19  194611110NYK   NBA        0     1947 1946-11-11
# 54             28  194611160NYK   NBA        0     1947 1946-11-16
# ...           ...           ...   ...      ...      ...        ...
# 126025      63013  201504080NYK   NBA        0     2015 2015-04-08
# 126056      63029  201504100NYK   NBA        0     2015 2015-04-10
# 126072      63037  201504110ORL   NBA        1     2015 2015-04-11
# 126094      63048  201504130ATL   NBA        1     2015 2015-04-13
# 126147      63074  201504150NYK   NBA        0     2015 2015-04-15
#
#         seasongame  is_playoffs team_id fran_id  pts  win_equiv opp_id  \
# 1                1            0     NYK  Knicks   68      41.71    TRH
# ...

# %%
nba[nba["fran_id"] == "Knicks"].groupby(["year_id", "pts"])

# %%
nba[nba["fran_id"] == "Knicks"].groupby(["year_id", "pts"]).sum()
# Out:
#              gameorder  _iscopy  seasongame  is_playoffs  win_equiv  opp_pts  \
# year_id pts
# 1947    45         165        0          29            0      41.03       58
#         46         387        0          69            0      76.05      123
#         47           2        1           2            0      40.69       63
#         48         208        1          38            0      35.77       49
#         49         429        2          77            0      87.08      121
# ...                ...      ...         ...          ...        ...      ...
# 2015    109      61990        0          11            0      37.02       93
#         112      63048        1          81            0      18.86      108
#         113     124496        1          56            0      59.94      223
#         121      62704        1          57            0      21.38      115
#         129      62296        1          32            0      27.54      135
#
# ...

# %%
nba[nba["fran_id"] == "Knicks"].groupby(["year_id"])["pts"].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba[nba["fran_id"] == "Knicks"].groupby(["year_id", "pts"]).sum().plot()
# Out:
# c:\Users\HP\anaconda3\envs\env\lib\site-packages\pandas\plotting\_matplotlib\core.py:677: UserWarning: The label '_iscopy' of <matplotlib.lines.Line2D object at 0x000001BA2DE1B970> starts with '_'. It is thus excluded from the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <Axes: xlabel='year_id,pts'>

# %%
nba["fran_id"].value_counts().head(10).plot()
# Out:
# <Axes: >

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64
